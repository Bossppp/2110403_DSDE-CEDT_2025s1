# %%
# import required libraries
from kafka import KafkaConsumer

# %%
import avro.schema
import avro.io
import io

# %%
schema_file = 'sample.avsc'
schema = avro.schema.parse(open(schema_file).read())

# %%
def deserialize(schema, raw_bytes):
    bytes_reader = io.BytesIO(raw_bytes)
    decoder = avro.io.BinaryDecoder(bytes_reader)
    reader = avro.io.DatumReader(schema)
    return reader.read(decoder)

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'localhost:9092'

# %%
consumer = KafkaConsumer(
    'avro',
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: deserialize(schema, x))

# %%
print('Running Consumer with AVRO')
for message in consumer:
    print(message.value)
# Out:
# Running Consumer with AVRO
# {'key': 'key1', 'value': 'message #1', 'timestamp': 1763567955253}
# {'key': 'key2', 'value': 'message #2', 'timestamp': 1763567957259}
# {'key': 'key3', 'value': 'message #3', 'timestamp': 1763567959263}
# {'key': 'key4', 'value': 'message #4', 'timestamp': 1763567961269}
# {'key': 'key5', 'value': 'message #5', 'timestamp': 1763567963274}
# {'key': 'key6', 'value': 'message #6', 'timestamp': 1763567965275}
# {'key': 'key7', 'value': 'message #7', 'timestamp': 1763567967281}
# {'key': 'key8', 'value': 'message #8', 'timestamp': 1763567969287}
# {'key': 'key9', 'value': 'message #9', 'timestamp': 1763567971293}
# {'key': 'key10', 'value': 'message #10', 'timestamp': 1763567973309}
# {'key': 'key11', 'value': 'message #11', 'timestamp': 1763567975311}
# {'key': 'key12', 'value': 'message #12', 'timestamp': 1763567977317}
# {'key': 'key13', 'value': 'message #13', 'timestamp': 1763567979321}
# {'key': 'key14', 'value': 'message #14', 'timestamp': 1763567981327}
# {'key': 'key15', 'value': 'message #15', 'timestamp': 1763567983329}
# {'key': 'key16', 'value': 'message #16', 'timestamp': 1763567985335}
# {'key': 'key17', 'value': 'message #17', 'timestamp': 1763567987338}
# {'key': 'key18', 'value': 'message #18', 'timestamp': 1763567989342}
# {'key': 'key19', 'value': 'message #19', 'timestamp': 1763567991345}
# {'key': 'key20', 'value': 'message #20', 'timestamp': 1763567993350}
# {'key': 'key21', 'value': 'message #21', 'timestamp': 1763567995352}
# {'key': 'key22', 'value': 'message #22', 'timestamp': 1763567997357}
# {'key': 'key23', 'value': 'message #23', 'timestamp': 1763567999361}
# {'key': 'key24', 'value': 'message #24', 'timestamp': 1763568001365}
# {'key': 'key25', 'value': 'message #25', 'timestamp': 1763568003370}
# {'key': 'key26', 'value': 'message #26', 'timestamp': 1763568005376}
# {'key': 'key27', 'value': 'message #27', 'timestamp': 1763568007382}
# {'key': 'key28', 'value': 'message #28', 'timestamp': 1763568009388}
# {'key': 'key29', 'value': 'message #29', 'timestamp': 1763568011394}
# {'key': 'key30', 'value': 'message #30', 'timestamp': 1763568013400}
# {'key': 'key31', 'value': 'message #31', 'timestamp': 1763568015404}
# {'key': 'key32', 'value': 'message #32', 'timestamp': 1763568017407}
# {'key': 'key33', 'value': 'message #33', 'timestamp': 1763568019413}
# {'key': 'key34', 'value': 'message #34', 'timestamp': 1763568021419}
# {'key': 'key35', 'value': 'message #35', 'timestamp': 1763568023424}
# {'key': 'key36', 'value': 'message #36', 'timestamp': 1763568025428}
# {'key': 'key37', 'value': 'message #37', 'timestamp': 1763568027435}
# {'key': 'key38', 'value': 'message #38', 'timestamp': 1763568029440}
# {'key': 'key39', 'value': 'message #39', 'timestamp': 1763568031446}
# {'key': 'key40', 'value': 'message #40', 'timestamp': 1763568033453}
# {'key': 'key41', 'value': 'message #41', 'timestamp': 1763568035459}
# {'key': 'key42', 'value': 'message #42', 'timestamp': 1763568037460}
# {'key': 'key43', 'value': 'message #43', 'timestamp': 1763568039468}
# {'key': 'key44', 'value': 'message #44', 'timestamp': 1763568041474}
# {'key': 'key45', 'value': 'message #45', 'timestamp': 1763568043478}
# {'key': 'key46', 'value': 'message #46', 'timestamp': 1763568045484}
# {'key': 'key47', 'value': 'message #47', 'timestamp': 1763568047491}
# {'key': 'key48', 'value': 'message #48', 'timestamp': 1763568049494}
# {'key': 'key49', 'value': 'message #49', 'timestamp': 1763568051498}
# {'key': 'key50', 'value': 'message #50', 'timestamp': 1763568053504}
# {'key': 'key51', 'value': 'message #51', 'timestamp': 1763568055510}
# {'key': 'key52', 'value': 'message #52', 'timestamp': 1763568057514}
# {'key': 'key53', 'value': 'message #53', 'timestamp': 1763568059521}
# {'key': 'key54', 'value': 'message #54', 'timestamp': 1763568061525}
# {'key': 'key55', 'value': 'message #55', 'timestamp': 1763568063531}
# {'key': 'key56', 'value': 'message #56', 'timestamp': 1763568065537}
# {'key': 'key57', 'value': 'message #57', 'timestamp': 1763568067542}
# {'key': 'key58', 'value': 'message #58', 'timestamp': 1763568069547}
# {'key': 'key59', 'value': 'message #59', 'timestamp': 1763568071552}
# {'key': 'key60', 'value': 'message #60', 'timestamp': 1763568073557}
# {'key': 'key61', 'value': 'message #61', 'timestamp': 1763568075559}
# {'key': 'key62', 'value': 'message #62', 'timestamp': 1763568077563}
# {'key': 'key63', 'value': 'message #63', 'timestamp': 1763568079569}
# {'key': 'key64', 'value': 'message #64', 'timestamp': 1763568081574}
# {'key': 'key65', 'value': 'message #65', 'timestamp': 1763568083580}
# {'key': 'key66', 'value': 'message #66', 'timestamp': 1763568085590}
# {'key': 'key67', 'value': 'message #67', 'timestamp': 1763568087596}
# {'key': 'key68', 'value': 'message #68', 'timestamp': 1763568089599}
# {'key': 'key69', 'value': 'message #69', 'timestamp': 1763568091604}
# {'key': 'key70', 'value': 'message #70', 'timestamp': 1763568093607}
# {'key': 'key71', 'value': 'message #71', 'timestamp': 1763568095614}
# {'key': 'key72', 'value': 'message #72', 'timestamp': 1763568097617}
# {'key': 'key73', 'value': 'message #73', 'timestamp': 1763568099619}
# {'key': 'key74', 'value': 'message #74', 'timestamp': 1763568101625}
# {'key': 'key75', 'value': 'message #75', 'timestamp': 1763568103631}
# {'key': 'key76', 'value': 'message #76', 'timestamp': 1763568105634}
# {'key': 'key77', 'value': 'message #77', 'timestamp': 1763568107635}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 print('Running Consumer with AVRO')
# ----> 2 for message in consumer:
#       3     print(message.value)
#
# File ~/anaconda3/envs/dsde/lib/python3.11/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~/anaconda3/envs/dsde/lib/python3.11/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~/anaconda3/envs/dsde/lib/python3.11/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~/anaconda3/envs/dsde/lib/python3.11/site-packages/kafka/consumer/group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~/anaconda3/envs/dsde/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/anaconda3/envs/dsde/lib/python3.11/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~/anaconda3/envs/dsde/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
